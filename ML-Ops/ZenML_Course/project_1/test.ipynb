# %%
import os, sys, shutil
from pathlib import Path

# full ZenML reset (local + global)
paths_to_remove = [
    Path(".zen"),  # project-local repo
    Path.home() / ".config" / "zenml",  # common global path
    Path(os.path.expandvars(r"%USERPROFILE%\.config\zenml")),
    Path(os.path.expandvars(r"%APPDATA%\zenml")),
]

for p in paths_to_remove:
    if p.exists():
        print("Removing:", p)
        shutil.rmtree(p, ignore_errors=True)

# init from terminal to avoid errors

# %% [markdown]
# # in terminal
# 1. zenml init
# 2. zenml login --blocking // [or] zenml up

# %%
from pipelines.training_pipeline import training_pipeline

training_pipeline(data_path="data/olist_customers_dataset.csv")
# Out:
# Initiating a new run for the pipeline: training_pipeline.
# Using user: default
# Using stack: default
#   deployer: default
#   orchestrator: default
#   artifact_store: default
# You can visualize your pipeline runs in the ZenML Dashboard. In order to try it locally, please run zenml login --local.
# Using cached version of step ingest_df.
# Using cached version of step eval_model.
# Using cached version of step train_model.
# Step clean_df has started.
# By default, the PandasMaterializer stores data as a .csv file. If you want to store data more efficiently, you can install pyarrow by running 'pip install pyarrow'. This will allow PandasMaterializer to automatically store the data as a .parquet file instead.
# c:\Users\YOUSSEF\Desktop\Machine Learning\.venv\lib\site-packages\zenml\integrations\pandas\materializers\pandas_materializer.py:144: UserWarning: Could not infer format, so each element will be parsed individually, falling back to dateutil. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(f, index_col=0, parse_dates=True)
#
# Step clean_df has finished in 1.583s.
# Pipeline run has finished in 2.314s.
# PipelineRunResponse(body=PipelineRunResponseBody(created=datetime.datetime(2026, 4, 20, 15, 8, 46, 164867), updated=datetime.datetime(2026, 4, 20, 15, 8, 48, 932261), user_id=UUID('69acf33a-cfdb-440e-84e3-6ab122c6c59e'), project_id=UUID('ac59455a-ebbf-4630-abfe-bf2e42adcbd7'), status=<ExecutionStatus.COMPLETED: 'completed'>, in_progress=False, status_reason=None, index=5), metadata=PipelineRunResponseMetadata(run_metadata={}, config=PipelineConfiguration(enable_cache=None, enable_artifact_metadata=None, enable_artifact_visualization=None, enable_step_logs=None, enable_heartbeat=None, environment={}, secrets=[], enable_pipeline_logs=None, execution_mode=<ExecutionMode.CONTINUE_ON_FAILURE: 'continue_on_failure'>, settings={}, tags=None, extra={}, failure_hook_source=None, success_hook_source=None, init_hook_source=None, init_hook_kwargs=None, cleanup_hook_source=None, model=None, parameters={'data_path': 'data/olist_customers_dataset.csv'}, retry=None, substitutions={'date': '2026_04_20', 'time': '15_08_46_159883'}, cache_policy=None, name='training_pipeline', steps_to_skip=set(), skip_successful_steps=False, step_input_overrides={}), start_time=datetime.datetime(2026, 4, 20, 15, 8, 46, 159883), end_time=datetime.datetime(2026, 4, 20, 15, 8, 48, 283424), client_environment={'environment': 'notebook', 'os': 'windows', 'windows_version_release': '10', 'windows_version': '10.0.19045', 'windows_version_service_pack': 'SP0', 'windows_version_os_type': 'Multiprocessor Free', 'python_version': '3.10.5', 'zenml_version': '0.94.2'}, orchestrator_environment={'environment': 'notebook', 'os': 'windows', 'windows_version_release': '10', 'windows_version': '10.0.19045', 'windows_version_service_pack': 'SP0', 'windows_version_os_type': 'Multiprocessor Free', 'python_version': '3.10.5', 'zenml_version': '0.94.2'}, orchestrator_run_id='1efd900a-2627-47f4-8c11-5ed873c6b729', code_path=None, template_id=None, is_templatable=False, trigger_info=None, enable_heartbeat=True, exception_info=None), resources=PipelineRunResponseResources(user=UserResponse(body=UserResponseBody(created=datetime.datetime(2026, 4, 14, 12, 37, 1, 315817), updated=datetime.datetime(2026, 4, 14, 12, 37, 48, 906839), active=True, activation_token=None, full_name='default', email_opted_in=False, is_service_account=False, is_admin=True, default_project_id=None, avatar_url=None), metadata=None, resources=None, id=UUID('69acf33a-cfdb-440e-84e3-6ab122c6c59e'), permission_denied=False, name='default'), snapshot=PipelineSnapshotResponse(body=PipelineSnapshotResponseBody(created=datetime.datetime(2026, 4, 20, 15, 8, 46, 133969), updated=datetime.datetime(2026, 4, 20, 15, 8, 46, 133969), user_id=UUID('69acf33a-cfdb-440e-84e3-6ab122c6c59e'), project_id=UUID('ac59455a-ebbf-4630-abfe-bf2e42adcbd7'), runnable=False, deployable=False, is_dynamic=False), metadata=None, resources=None, id=UUID('a840551f-57f5-48fd-a123-4324d5e2263a'), permission_denied=False, name=None), source_snapshot=None, stack=StackResponse(body=StackResponseBody(created=datetime.datetime(2026, 4, 14, 12, 37, 1, 78589), updated=datetime.datetime(2026, 4, 14, 12, 37, 1, 78589), user_id=None), metadata=None, resources=None, id=UUID('9b6e86b9-ee3e-4970-93f7-a04c1ec1434b'), permission_denied=False, name='default'), pipeline=PipelineResponse(body=PipelineResponseBody(created=datetime.datetime(2026, 4, 20, 14, 53, 10, 89877), updated=datetime.datetime(2026, 4, 20, 14, 53, 10, 89877), user_id=UUID('69acf33a-cfdb-440e-84e3-6ab122c6c59e'), project_id=UUID('ac59455a-ebbf-4630-abfe-bf2e42adcbd7')), metadata=None, resources=None, id=UUID('2835eb1c-3052-4eda-963e-739e70767cb8'), permission_denied=False, name='training_pipeline'), build=None, schedule=None, code_reference=None, model_version=None, tags=[], log_collection=[LogsResponse(body=LogsResponseBody(created=datetime.datetime(2026, 4, 20, 15, 8, 45, 302750), updated=datetime.datetime(2026, 4, 20, 15, 8, 45, 302750), user_id=UUID('69acf33a-cfdb-440e-84e3-6ab122c6c59e'), project_i ...
